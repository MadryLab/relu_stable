# %%
# Model Training

# To fully train the model, change max_num_training_steps = 100000 in config.json
# A fully trained model will be more ReLU stable and hence much faster to verify.
# !python train.py
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# 2018-10-06 16:57:32.412647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:955] Found device 0 with properties:
# name: GeForce GTX 1080 Ti
# major: 6 minor: 1 memoryClockRate (GHz) 1.582
# pciBusID 0000:0d:00.0
# Total memory: 10.91GiB
# Free memory: 10.75GiB
# 2018-10-06 16:57:32.412708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:976] DMA: 0
# 2018-10-06 16:57:32.412719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:986] 0:   Y
# 2018-10-06 16:57:32.412732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1045] Creating TensorFlow device (/gpu:0) -> (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:0d:00.0)
#     Step 0:    (2018-10-06 16:57:34.573829)
#     training nat accuracy 12.5%
#     training adv accuracy 6.25%
#     Step 100:    (2018-10-06 16:57:38.901478)
#     training nat accuracy 51.56%
#     training adv accuracy 35.94%
#     1150.9876056643382 examples per second
#     Step 200:    (2018-10-06 16:57:43.343440)
#     training nat accuracy 84.38%
#     training adv accuracy 75.0%
#     1456.6075491505321 examples per second
#     Step 300:    (2018-10-06 16:57:47.469439)
#     training nat accuracy 79.69%
#     training adv accuracy 68.75%
#     1567.764702310838 examples per second
#     Step 400:    (2018-10-06 16:57:51.405958)
#     training nat accuracy 89.06%
#     training adv accuracy 84.38%
#     1643.6974354856472 examples per second
#     Step 500:    (2018-10-06 16:57:55.327251)
#     training nat accuracy 85.94%
#     training adv accuracy 78.12%
#     1654.9656077399657 examples per second
#     Step 600:    (2018-10-06 16:57:59.472467)
#     training nat accuracy 82.81%
#     training adv accuracy 75.0%
#     1628.5194706351601 examples per second
#     Step 700:    (2018-10-06 16:58:03.434299)
#     training nat accuracy 95.31%
#     training adv accuracy 87.5%
#     1633.0458424024393 examples per second
#     Step 800:    (2018-10-06 16:58:06.955696)
#     training nat accuracy 92.19%
#     training adv accuracy 90.62%
#     1836.4474741720924 examples per second
#     Step 900:    (2018-10-06 16:58:10.654174)
#     training nat accuracy 79.69%
#     training adv accuracy 65.62%
#     1756.1252452874858 examples per second
#     Step 1000:    (2018-10-06 16:58:14.406344)
#     training nat accuracy 89.06%
#     training adv accuracy 79.69%
#     1724.1403401446166 examples per second
#     Step 1100:    (2018-10-06 16:58:17.947800)
#     training nat accuracy 93.75%
#     training adv accuracy 90.62%
#     1886.2832494310105 examples per second
#     Step 1200:    (2018-10-06 16:58:21.454253)
#     training nat accuracy 93.75%
#     training adv accuracy 75.0%
#     1845.2520466006524 examples per second
#     Step 1300:    (2018-10-06 16:58:24.906246)
#     training nat accuracy 92.19%
#     training adv accuracy 85.94%
#     1872.256643410206 examples per second
#     Step 1400:    (2018-10-06 16:58:28.573625)
#     training nat accuracy 84.38%
#     training adv accuracy 78.12%
#     1762.7157315975462 examples per second
#     Step 1500:    (2018-10-06 16:58:31.969825)
#     training nat accuracy 90.62%
#     training adv accuracy 78.12%
#     1904.0726876039957 examples per second
#     Step 1600:    (2018-10-06 16:58:35.683420)
#     training nat accuracy 90.62%
#     training adv accuracy 76.56%
#     1795.5214281536523 examples per second
#     Step 1700:    (2018-10-06 16:58:39.417995)
#     training nat accuracy 93.75%
#     training adv accuracy 87.5%
#     1728.2715243644095 examples per second
#     Step 1800:    (2018-10-06 16:58:43.011012)
#     training nat accuracy 92.19%
#     training adv accuracy 84.38%
#     1797.4444364233225 examples per second
#     Step 1900:    (2018-10-06 16:58:46.421864)
#     training nat accuracy 92.19%
#     training adv accuracy 84.38%
#     1896.382920829954 examples per second
#     Step 2000:    (2018-10-06 16:58:50.151172)
#     training nat accuracy 95.31%
#     training adv accuracy 90.62%
#     1732.1496485992354 examples per second
# 100%|###########################################| 50/50 [00:13<00:00,  3.72it/s]
# Eval at 2000:
#   natural: 93.44%
#   adversarial: 54.66%
#   avg nat loss: 0.0012
#   avg adv loss: 0.0061
#   unstablerelus1, unstablerelus2, unstablerelus3: 246.2977, 1463.1885, 100.0
#   ur1loss, ur2loss, ur3loss: -6.251956853866579e-06, -9.439934390783311e-07, 4.910080802917482e-05
#     Step 2100:    (2018-10-06 16:59:07.128145)
#     training nat accuracy 92.19%
#     training adv accuracy 81.25%
#     1918.60049433308 examples per second
#     Step 2200:    (2018-10-06 16:59:11.000948)
#     training nat accuracy 90.62%
#     training adv accuracy 89.06%
#     1670.7653143627263 examples per second
#     Step 2300:    (2018-10-06 16:59:14.476895)
#     training nat accuracy 93.75%
#     training adv accuracy 89.06%
#     1859.4912551590949 examples per second
#     Step 2400:    (2018-10-06 16:59:18.211352)
#     training nat accuracy 93.75%
#     training adv accuracy 84.38%
#     1730.565426556834 examples per second
#     Step 2500:    (2018-10-06 16:59:21.666375)
#     training nat accuracy 90.62%
#     training adv accuracy 82.81%
#     1872.023807706167 examples per second
#     Step 2600:    (2018-10-06 16:59:25.314340)
#     training nat accuracy 93.75%
#     training adv accuracy 79.69%
#     1877.3254252003962 examples per second
#     Step 2700:    (2018-10-06 16:59:28.754269)
#     training nat accuracy 96.88%
#     training adv accuracy 85.94%
#     1893.1005290327341 examples per second
#     Step 2800:    (2018-10-06 16:59:32.390895)
#     training nat accuracy 95.31%
#     training adv accuracy 81.25%
#     1774.7998525668838 examples per second
#     Step 2900:    (2018-10-06 16:59:35.983051)
#     training nat accuracy 95.31%
#     training adv accuracy 84.38%
#     1796.8834993382143 examples per second
#     Step 3000:    (2018-10-06 16:59:39.420817)
#     training nat accuracy 92.19%
#     training adv accuracy 73.44%
#     1880.730832212532 examples per second
#     Step 3100:    (2018-10-06 16:59:43.071244)
#     training nat accuracy 92.19%
#     training adv accuracy 78.12%
#     1834.8992625638577 examples per second
#     Step 3200:    (2018-10-06 16:59:46.578998)
#     training nat accuracy 93.75%
#     training adv accuracy 82.81%
#     1839.3923461372347 examples per second
#     Step 3300:    (2018-10-06 16:59:50.168571)
#     training nat accuracy 93.75%
#     training adv accuracy 82.81%
#     1796.5633032617552 examples per second
#     Step 3400:    (2018-10-06 16:59:53.799463)
#     training nat accuracy 98.44%
#     training adv accuracy 87.5%
#     1776.768509686099 examples per second
#     Step 3500:    (2018-10-06 16:59:57.358160)
#     training nat accuracy 93.75%
#     training adv accuracy 73.44%
#     1814.6453053177231 examples per second
#     Step 3600:    (2018-10-06 17:00:01.198553)
#     training nat accuracy 96.88%
#     training adv accuracy 79.69%
#     1784.603588482822 examples per second
#     Step 3700:    (2018-10-06 17:00:04.881087)
#     training nat accuracy 93.75%
#     training adv accuracy 81.25%
#     1751.7306892856336 examples per second
#     Step 3800:    (2018-10-06 17:00:08.408224)
#     training nat accuracy 96.88%
#     training adv accuracy 79.69%
#     1828.6047790732134 examples per second
#     Step 3900:    (2018-10-06 17:00:12.183789)
#     training nat accuracy 92.19%
#     training adv accuracy 73.44%
#     1708.0496490873636 examples per second
#     Step 4000:    (2018-10-06 17:00:15.860270)
#     training nat accuracy 95.31%
#     training adv accuracy 81.25%
#     1756.367400672501 examples per second
# 100%|###########################################| 50/50 [00:14<00:00,  3.56it/s]
# Eval at 4000:
#   natural: 95.71%
#   adversarial: 75.97%
#   avg nat loss: 0.0008
#   avg adv loss: 0.0035
#   unstablerelus1, unstablerelus2, unstablerelus3: 200.8676, 1262.33, 99.3984
#   ur1loss, ur2loss, ur3loss: -6.262487144470213e-06, -9.463475418090823e-06, 4.73620922088623e-05
#     Step 4100:    (2018-10-06 17:00:33.844112)
#     training nat accuracy 89.06%
#     training adv accuracy 73.44%
#     1737.366232352502 examples per second
#     Step 4200:    (2018-10-06 17:00:37.430897)
#     training nat accuracy 95.31%
#     training adv accuracy 85.94%
#     1801.1469759040071 examples per second
#     Step 4300:    (2018-10-06 17:00:40.840420)
#     training nat accuracy 93.75%
#     training adv accuracy 73.44%
#     1895.8439907911034 examples per second
#     Step 4400:    (2018-10-06 17:00:44.691119)
#     training nat accuracy 98.44%
#     training adv accuracy 87.5%
#     1674.2859951818373 examples per second
#     Step 4500:    (2018-10-06 17:00:48.180036)
#     training nat accuracy 93.75%
#     training adv accuracy 75.0%
#     1848.8114102110587 examples per second
#     Step 4600:    (2018-10-06 17:00:52.156401)
#     training nat accuracy 95.31%
#     training adv accuracy 87.5%
#     1688.6623199015912 examples per second
#     Step 4700:    (2018-10-06 17:00:55.815594)
#     training nat accuracy 100.0%
#     training adv accuracy 84.38%
#     1761.4128188797974 examples per second
#     Step 4800:    (2018-10-06 17:00:59.389944)
#     training nat accuracy 93.75%
#     training adv accuracy 82.81%
#     1816.959908617516 examples per second
#     Step 4900:    (2018-10-06 17:01:02.931618)
#     training nat accuracy 96.88%
#     training adv accuracy 76.56%
#     1825.4736520323515 examples per second
#     Step 5000:    (2018-10-06 17:01:06.540499)
#     training nat accuracy 96.88%
#     training adv accuracy 85.94%
#     1790.3795232997352 examples per second
#     Step 5100:    (2018-10-06 17:01:10.429171)
#     training nat accuracy 93.75%
#     training adv accuracy 84.38%
#     1727.0841135490093 examples per second
#     Step 5200:    (2018-10-06 17:01:13.782645)
#     training nat accuracy 96.88%
#     training adv accuracy 78.12%
#     1923.7273225838535 examples per second
#     Step 5300:    (2018-10-06 17:01:17.438198)
#     training nat accuracy 96.88%
#     training adv accuracy 73.44%
#     1762.4462859676291 examples per second
#     Step 5400:    (2018-10-06 17:01:20.894533)
#     training nat accuracy 93.75%
#     training adv accuracy 79.69%
#     1867.0992988940113 examples per second
#     Step 5500:    (2018-10-06 17:01:24.659960)
#     training nat accuracy 96.88%
#     training adv accuracy 84.38%
#     1714.632575833367 examples per second
#     Step 5600:    (2018-10-06 17:01:28.160367)
#     training nat accuracy 92.19%
#     training adv accuracy 76.56%
#     1917.3106324034734 examples per second
#     Step 5700:    (2018-10-06 17:01:31.767464)
#     training nat accuracy 92.19%
#     training adv accuracy 73.44%
#     1790.7505032987956 examples per second
#     Step 5800:    (2018-10-06 17:01:35.396867)
#     training nat accuracy 93.75%
#     training adv accuracy 79.69%
#     1778.7239660029445 examples per second
#     Step 5900:    (2018-10-06 17:01:38.806578)
#     training nat accuracy 98.44%
#     training adv accuracy 82.81%
#     1892.6388028861338 examples per second
#     Step 6000:    (2018-10-06 17:01:42.195665)
#     training nat accuracy 98.44%
#     training adv accuracy 89.06%
#     1902.5535919360457 examples per second
# 100%|###########################################| 50/50 [00:13<00:00,  3.71it/s]
# Eval at 6000:
#   natural: 96.26%
#   adversarial: 83.78%
#   avg nat loss: 0.0007
#   avg adv loss: 0.0025
#   unstablerelus1, unstablerelus2, unstablerelus3: 570.2424, 984.5668, 94.0469
#   ur1loss, ur2loss, ur3loss: -6.245318355560302e-06, -1.174699644088745e-05, 4.367475517272949e-05
#     Step 6100:    (2018-10-06 17:01:59.744757)
#     training nat accuracy 95.31%
#     training adv accuracy 81.25%
#     1640.4918088897548 examples per second
#     Step 6200:    (2018-10-06 17:02:03.003680)
#     training nat accuracy 89.06%
#     training adv accuracy 78.12%
#     1983.7666133323883 examples per second
#     Step 6300:    (2018-10-06 17:02:06.701722)
#     training nat accuracy 96.88%
#     training adv accuracy 81.25%
#     1745.5183128330798 examples per second
#     Step 6400:    (2018-10-06 17:02:10.134454)
#     training nat accuracy 95.31%
#     training adv accuracy 76.56%
#     1880.6837079431705 examples per second
#     Step 6500:    (2018-10-06 17:02:13.810518)
#     training nat accuracy 93.75%
#     training adv accuracy 73.44%
#     1755.0274165603244 examples per second
#     Step 6600:    (2018-10-06 17:02:17.357939)
#     training nat accuracy 96.88%
#     training adv accuracy 79.69%
#     1888.7640909510023 examples per second
#     Step 6700:    (2018-10-06 17:02:20.843111)
#     training nat accuracy 100.0%
#     training adv accuracy 87.5%
#     1852.1507536821985 examples per second
#     Step 6800:    (2018-10-06 17:02:24.452431)
#     training nat accuracy 98.44%
#     training adv accuracy 89.06%
#     1789.6554894216247 examples per second
#     Step 6900:    (2018-10-06 17:02:27.955897)
#     training nat accuracy 93.75%
#     training adv accuracy 78.12%
#     1842.6844444370008 examples per second
#     Step 7000:    (2018-10-06 17:02:31.287589)
#     training nat accuracy 96.88%
#     training adv accuracy 89.06%
#     1936.0689411992462 examples per second
#     Step 7100:    (2018-10-06 17:02:35.200970)
#     training nat accuracy 93.75%
#     training adv accuracy 78.12%
#     1771.6763225372804 examples per second
#     Step 7200:    (2018-10-06 17:02:38.636586)
#     training nat accuracy 96.88%
#     training adv accuracy 79.69%
#     1877.5286263808384 examples per second
#     Step 7300:    (2018-10-06 17:02:42.339663)
#     training nat accuracy 95.31%
#     training adv accuracy 81.25%
#     1740.617990305091 examples per second
#     Step 7400:    (2018-10-06 17:02:45.835740)
#     training nat accuracy 96.88%
#     training adv accuracy 78.12%
#     1843.918135869425 examples per second
#     Step 7500:    (2018-10-06 17:02:49.459461)
#     training nat accuracy 98.44%
#     training adv accuracy 89.06%
#     1778.5124472262964 examples per second
#     Step 7600:    (2018-10-06 17:02:53.229554)
#     training nat accuracy 96.88%
#     training adv accuracy 90.62%
#     1809.7331673390174 examples per second
#     Step 7700:    (2018-10-06 17:02:56.586560)
#     training nat accuracy 96.88%
#     training adv accuracy 85.94%
#     1924.9560361813128 examples per second
#     Step 7800:    (2018-10-06 17:03:00.171752)
#     training nat accuracy 96.88%
#     training adv accuracy 89.06%
#     1801.6817791604299 examples per second
#     Step 7900:    (2018-10-06 17:03:03.657738)
#     training nat accuracy 98.44%
#     training adv accuracy 81.25%
#     1852.008228401002 examples per second
#     Step 8000:    (2018-10-06 17:03:07.107640)
#     training nat accuracy 95.31%
#     training adv accuracy 82.81%
#     1870.6194573721618 examples per second
# 100%|###########################################| 50/50 [00:13<00:00,  3.65it/s]
# Eval at 8000:
#   natural: 96.95%
#   adversarial: 87.73%
#   avg nat loss: 0.0006
#   avg adv loss: 0.0019
#   unstablerelus1, unstablerelus2, unstablerelus3: 565.7093, 610.0093, 91.2709
#   ur1loss, ur2loss, ur3loss: -6.227583513259889e-06, -1.2514928474426277e-05, 4.174184631347655e-05
#     Step 8100:    (2018-10-06 17:03:24.501169)
#     training nat accuracy 98.44%
#     training adv accuracy 92.19%
#     1835.006334351512 examples per second
#     Step 8200:    (2018-10-06 17:03:28.154974)
#     training nat accuracy 95.31%
#     training adv accuracy 90.62%
#     1767.5565211582186 examples per second
#     Step 8300:    (2018-10-06 17:03:31.738490)
#     training nat accuracy 95.31%
#     training adv accuracy 89.06%
#     1801.199559000032 examples per second
#     Step 8400:    (2018-10-06 17:03:35.504118)
#     training nat accuracy 96.88%
#     training adv accuracy 78.12%
#     1713.091621188578 examples per second
#     Step 8500:    (2018-10-06 17:03:39.280786)
#     training nat accuracy 93.75%
#     training adv accuracy 84.38%
#     1707.9581472575044 examples per second
#     Step 8600:    (2018-10-06 17:03:43.170636)
#     training nat accuracy 98.44%
#     training adv accuracy 89.06%
#     1711.136994031439 examples per second
#     Step 8700:    (2018-10-06 17:03:46.828633)
#     training nat accuracy 93.75%
#     training adv accuracy 84.38%
#     1770.6486848523473 examples per second
#     Step 8800:    (2018-10-06 17:03:50.336262)
#     training nat accuracy 98.44%
#     training adv accuracy 82.81%
#     1841.1146742983938 examples per second
#     Step 8900:    (2018-10-06 17:03:54.056112)
#     training nat accuracy 98.44%
#     training adv accuracy 84.38%
#     1745.228908264339 examples per second
#     Step 9000:    (2018-10-06 17:03:57.519672)
#     training nat accuracy 95.31%
#     training adv accuracy 85.94%
#     1862.2182313896349 examples per second
#     Step 9100:    (2018-10-06 17:04:01.349712)
#     training nat accuracy 100.0%
#     training adv accuracy 92.19%
#     1744.0493102409857 examples per second
#     Step 9200:    (2018-10-06 17:04:05.287353)
#     training nat accuracy 96.88%
#     training adv accuracy 90.62%
#     1636.3942757937536 examples per second
#     Step 9300:    (2018-10-06 17:04:08.820041)
#     training nat accuracy 96.88%
#     training adv accuracy 87.5%
#     1823.426013177951 examples per second
#     Step 9400:    (2018-10-06 17:04:12.408248)
#     training nat accuracy 95.31%
#     training adv accuracy 92.19%
#     1796.259053265698 examples per second
#     Step 9500:    (2018-10-06 17:04:15.964726)
#     training nat accuracy 98.44%
#     training adv accuracy 96.88%
#     1818.4221350043867 examples per second
#     Step 9600:    (2018-10-06 17:04:19.895930)
#     training nat accuracy 100.0%
#     training adv accuracy 95.31%
#     1783.8683597943254 examples per second
#     Step 9700:    (2018-10-06 17:04:23.632915)
#     training nat accuracy 95.31%
#     training adv accuracy 89.06%
#     1726.9001969851129 examples per second
#     Step 9800:    (2018-10-06 17:04:27.240485)
#     training nat accuracy 93.75%
#     training adv accuracy 90.62%
#     1788.0604153469887 examples per second
#     Step 9900:    (2018-10-06 17:04:30.991664)
#     training nat accuracy 98.44%
#     training adv accuracy 87.5%
#     1718.8794723492094 examples per second
#     Step 10000:    (2018-10-06 17:04:34.527842)
#     training nat accuracy 96.88%
#     training adv accuracy 82.81%
#     1822.7002907193162 examples per second
# 100%|###########################################| 50/50 [00:13<00:00,  3.63it/s]
# Eval at 10000:
#   natural: 97.31%
#   adversarial: 90.06%
#   avg nat loss: 0.0005
#   avg adv loss: 0.0016
#   unstablerelus1, unstablerelus2, unstablerelus3: 626.8293, 372.4959, 91.9366
#   ur1loss, ur2loss, ur3loss: -6.2133183479309104e-06, -1.2746685199737548e-05, 4.1690194168090835e-05

# %%
# Post process the model and convert it into a .mat file
# We specify the --do_eval flag to evaluate the accuracy and
# ReLU stability of the model before and after post-processing steps.
# We specify the --no_relu_prune flag to skip ReLU pruning
# !python post_process_model.py --model_dir 'trained_models/relu_stable' --output example --do_eval --no_relu_prune
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Processing model from trained_models/relu_stable
# 2018-10-06 17:05:00.293195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:955] Found device 0 with properties:
# name: GeForce GTX 1080 Ti
# major: 6 minor: 1 memoryClockRate (GHz) 1.582
# pciBusID 0000:0d:00.0
# Total memory: 10.91GiB
# Free memory: 10.75GiB
# 2018-10-06 17:05:00.293260: I tensorflow/core/common_runtime/gpu/gpu_device.cc:976] DMA: 0
# 2018-10-06 17:05:00.293270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:986] 0:   Y
# 2018-10-06 17:05:00.293281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1045] Creating TensorFlow device (/gpu:0) -> (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:0d:00.0)
# restored checkpoint for trained_models/relu_stable/checkpoint-10000
# First eval - no changes
# natural: 97.31%
# adversarial: 90.15%
#   un1n, un2n, un3n: 626.8293, 372.4959, 91.9366
# Second eval - prune small weights
# remaining nonzero weights: 187
# remaining weights proportion: 0.4675
# remaining nonzero weights: 3431
# remaining weights proportion: 0.268046875
# remaining nonzero weights: 130175
# remaining weights proportion: 0.8301977040816326
# natural: 97.35%
# adversarial: 90.11%
#   un1n, un2n, un3n: 551.3183, 368.706, 92.0925
# Saving model now

# %%
# We verify just the first 2 images against eps=0.1 for brevity's sake
# If you do not pass in a starting and ending index, it will
# verify the entire test set.
# !./verification/verify.sh example 0.1 1 2
# Out:
# example
# Computing fraction correct...100%|ââââââââââââââââââââââ| Time: 0:00:33
# Fraction correct: 0.9735
# Verifying 1 through 2
# Academic license - for non-commercial use only
# Academic license - for non-commercial use only
# [info | MIPVerify]: Working on index 1
# [notice | MIPVerify]: Attempting to find adversarial example. Neural net predicted label is 8, target labels are [1, 2, 3, 4, 5, 6, 7, 9, 10]
# [notice | MIPVerify]: Rebuilding model from scratch. This may take some time as we determine upper and lower bounds for the input to each non-linear unit.
# [info | MIPVerify]: Applying Flatten() ...
# [info | MIPVerify]: Applying Linear(784 -> 3136) ...
# [info | MIPVerify]: Applying ReLU() ...
#   Calculating upper bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:00
#   Calculating lower bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:00
# [info | MIPVerify]:   Behavior of ReLUs - split: 579, zero_output: 152, linear_in_input: 1958, constant_output: 447
#   Imposing relu constraint: 100%|âââââââââââââââââââââââ| Time: 0:00:00
# [info | MIPVerify]: Applying Linear(3136 -> 1568) ...
# [info | MIPVerify]: Applying ReLU() ...
#   Calculating upper bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:14
#   Calculating lower bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:03
# [info | MIPVerify]:   Behavior of ReLUs - split: 237, zero_output: 140, linear_in_input: 1191, constant_output: 0
#   Imposing relu constraint: 100%|âââââââââââââââââââââââ| Time: 0:00:00
# [info | MIPVerify]: Applying Linear(1568 -> 100) ...
# [info | MIPVerify]: Applying ReLU() ...
#   Calculating upper bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:10
#   Calculating lower bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:06
# [info | MIPVerify]:   Behavior of ReLUs - split: 33, zero_output: 11, linear_in_input: 56, constant_output: 0
# [info | MIPVerify]: Applying Linear(100 -> 10) ...
#   Calculating upper bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:06
#   Calculating lower bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:06
# [info | MIPVerify]: Number of inputs to maximum function possibly taking maximum value: 5
# Optimize a model with 6544 rows, 4057 columns and 238366 nonzeros
# Variable types: 3203 continuous, 854 integer (854 binary)
# Coefficient statistics:
#   Matrix range     [5e-08, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [4e-04, 4e+00]
#   RHS range        [1e-04, 9e+00]
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R786 by 0.056153915
#
# Presolve removed 2975 rows and 1457 columns
# Presolve time: 0.42s
#
# Explored 0 nodes (0 simplex iterations) in 0.57 seconds
# Thread count was 1 (of 40 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
# WARNING: Gurobi reported infeasible or unbounded. Set InfUnbdInfo=1 for more specific status.
# WARNING: Not solved to optimality, status: InfeasibleOrUnbounded
# [info | MIPVerify]: Working on index 2
# [notice | MIPVerify]: Attempting to find adversarial example. Neural net predicted label is 3, target labels are [1, 2, 4, 5, 6, 7, 8, 9, 10]
# [notice | MIPVerify]: Rebuilding model from scratch. This may take some time as we determine upper and lower bounds for the input to each non-linear unit.
# [info | MIPVerify]: Applying Flatten() ...
# [info | MIPVerify]: Applying Linear(784 -> 3136) ...
# [info | MIPVerify]: Applying ReLU() ...
# [info | MIPVerify]:   Behavior of ReLUs - split: 533, zero_output: 192, linear_in_input: 1964, constant_output: 447
# [info | MIPVerify]: Applying Linear(3136 -> 1568) ...
# [info | MIPVerify]: Applying ReLU() ...
#   Calculating upper bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:08
#   Calculating lower bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:02
# [info | MIPVerify]:   Behavior of ReLUs - split: 236, zero_output: 202, linear_in_input: 1130, constant_output: 0
# [info | MIPVerify]: Applying Linear(1568 -> 100) ...
# [info | MIPVerify]: Applying ReLU() ...
#   Calculating upper bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:07
#   Calculating lower bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:04
# [info | MIPVerify]:   Behavior of ReLUs - split: 29, zero_output: 20, linear_in_input: 51, constant_output: 0
# [info | MIPVerify]: Applying Linear(100 -> 10) ...
#   Calculating upper bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:04
#   Calculating lower bounds: 100%|âââââââââââââââââââââââ| Time: 0:00:05
# [info | MIPVerify]: Number of inputs to maximum function possibly taking maximum value: 6
# Optimize a model with 6342 rows, 3956 columns and 219098 nonzeros
# Variable types: 3152 continuous, 804 integer (804 binary)
# Coefficient statistics:
#   Matrix range     [2e-08, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-03, 4e+00]
#   RHS range        [5e-04, 8e+00]
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R786 by 0.035628409
#
# Presolve removed 2989 rows and 1570 columns
# Presolve time: 0.72s
# Presolved: 3353 rows, 2386 columns, 210739 nonzeros
# Variable types: 1584 continuous, 802 integer (802 binary)
#
# Root relaxation: infeasible, 341 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    1s
#
# Explored 0 nodes (341 simplex iterations) in 1.46 seconds
# Thread count was 32 (of 40 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
# WARNING: Not solved to optimality, status: InfeasibleOrUnbounded

# %%
# Parse the result file
# !python parser/parse_csv.py --csv_name './verification/results/example__linf-norm-bounded-0.1__Inf__0.0/summary.csv'
# Out:
# ProcessedSolveStatus                                ProvablyRobust
# ./verification/results/example__linf-norm-bound...               2
#                                                     BuildTime  SolveTime  \
# ./verification/results/example__linf-norm-bound...  54.631687   1.013723
#
#                                                     TotalTime
# ./verification/results/example__linf-norm-bound...   55.64541

# %%
# Parse the log file
# !./parser/convert_log.sh 'example'
# !python parser/parse_log.py --log_name 'example'
# Out:
# For file verification/logs/example.csv, it has 823.5 unstable relus on average
# Layer 1: 556.0, Layer 2: 236.5, Layer 3: 31.0
